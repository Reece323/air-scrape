# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import numpy as np

# %%
airbnb_url = 'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo'

def get_listings(search_page):
    answer = requests.get(search_page, timeout=5)
    content = answer.content
    soup = BeautifulSoup(requests.get(airbnb_url).content, 'html.parser')
    listings = soup.find_all('div', 'cm4lcvy dir dir-ltr')

    return listings

listings = get_listings(airbnb_url)

print(f'Number of listings per page: {len(listings)}\n\n')
# Out:
# Number of listings per page: 20

# %%
RULES_SEARCH_PAGE = {
    'url': {'tag': 'a', 'get': 'href'},
    'name': {'tag': 'span', 'class': 'ts5gl90 tl3qa0j t1nzedvd dir dir-ltr'},
    'header': {'tag': 'div', 'class': 'cuu4odx c1frjvtt dir dir-ltr'},
    'guests': {'tag': 'span', 'class': 'mp2hv9t dir dir-ltr', 'order': 0},
    'rooms': {'tag': 'span', 'class': 'mp2hv9t dir dir-ltr', 'order': 1},
    'beds': {'tag': 'span', 'class': 'mp2hv9t dir dir-ltr', 'order': 2},
    'baths': {'tag': 'span', 'class': 'mp2hv9t dir dir-ltr', 'order': 3},
    'facilities': {'tag': 'div', 'class': 'i1wgresd dir dir-ltr', 'order': 1},
    'badge': {'tag': 'div', 'class': 'fcg8kp6 dir dir-ltr'},
    'rating': {'tag': 'span', 'class': 'rpz7y38 dir dir-ltr'},
    'review_count': {'tag': 'span', 'class': 'r1xr6rtg dir dir-ltr'},
    'price': {'tag': 'span', 'class': '_tyxjp1'},
}


def extract_element(listing_html, params):
    # 1. Finding the right tag
    if 'class' in params:
        elements_found = listing_html.find_all(params['tag'], params['class'])
    else:
        elements_found = listing_html.find_all(params['tag'])

    # 2. Extracting the right element
    tag_order = params.get('order', 0)
    element = elements_found[tag_order]
        
    # 3. Getting text
    if 'get' in params:
        output = element.get(params['get'])
    else:
        output = element.get_text()

    return output


def extract_page_features(soup, rules):
    features_dict = {}
    for feature in rules:
        try:
            features_dict[feature] = extract_element(soup, rules[feature])
        except:
            features_dict[feature] = 'empty'
    
    return features_dict

extract_page_features(listings[0], RULES_SEARCH_PAGE)
# Out:
# {'url': '/rooms/585336259071491593?adults=8&children=0&infants=0&check_in=2023-02-24&check_out=2023-02-26&previous_page_section_name=1000&federated_search_id=9a5b8dd4-e7e2-4987-9d19-121e7678c84f',
#  'name': 'Pink Door ✰ Coler MTN Bike Preserve ✰ Family Flow',
#  'header': 'Entire residential home in Bentonville',
#  'guests': '8 guests',
#  'rooms': '4 bedrooms',
#  'beds': '5 beds',
#  'baths': '3 baths',
#  'facilities': 'Wifi · Kitchen · Free parking',
#  'badge': 'SUPERHOST',
#  'rating': 'empty',
#  'review_count': 'empty',
#  'price': '$189'}

# %%
##### Pagination
def build_urls(main_url, listings_per_page=20, pages_per_location=15):
    url_list = []
    for i in range(pages_per_location):
        offset = listings_per_page * i
        url_pagination = main_url + f'&items_offset={offset}'
        url_list.append(url_pagination)
    
    return url_list

url_list = build_urls(airbnb_url)

url_list
# Out:
# ['https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=0',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=20',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=40',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=60',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=80',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=100',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=120',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=140',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=160',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=180',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=200',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=220',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=240',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=260',
#  'https://www.airbnb.com/s/Bentonville--Arkansas--United-States/homes?adults=8&tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&query=Bentonville%2C%20Arkansas%2C%20United%20States&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=flexible_dates&search_type=autocomplete_click&checkin=2022-05-13&checkout=2022-05-15&source=structured_search_input_header&place_id=ChIJSUnWTgAQyYcRAr8lJMiMgNo&items_offset=280']

# %%
def process_search_pages(url_list):
    features_list = []
    for page in url_list:
        listings = get_listings(page)
        for listing in listings:
            features = extract_page_features(listing, RULES_SEARCH_PAGE)
            features_list.append(features)

    return features_list

# trying for one page

base_features = process_search_pages(url_list)

base_features
# Out:
# [{'url': '/rooms/585336259071491593?adults=8&children=0&infants=0&check_in=2023-01-20&check_out=2023-01-22&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'Pink Door ✰ Coler MTN Bike Preserve ✰ Family Flow',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$189'},
#  {'url': '/rooms/47883859?adults=8&children=0&infants=0&check_in=2023-02-10&check_out=2023-02-12&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'the PALMETTO/Near future WMHO/Greenway/8th St mkt',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '14 guests',
#   'rooms': '4 bedrooms',
#   'beds': '7 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.99',
#   'review_count': '\xa0(69 reviews)',
#   'price': '$197'},
#  {'url': '/rooms/39864150?adults=8&children=0&infants=0&check_in=2022-11-11&check_out=2022-11-13&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'Pintell Trails: Spacious 4 Bed, 3 Bath w/ Garage',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '4 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'empty',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$150'},
#  {'url': '/rooms/47701526?adults=8&children=0&infants=0&check_in=2022-10-28&check_out=2022-10-30&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'Pool/HotTub, Firepit Mile to Slaughter Pen & town',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.97',
#   'review_count': '\xa0(91 reviews)',
#   'price': '$438'},
#  {'url': '/rooms/583586116688149847?adults=8&children=0&infants=0&check_in=2023-01-20&check_out=2023-01-22&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': '[!!NEW!!] •The Hummingbird House•',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '10 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'empty',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$165'},
#  {'url': '/rooms/50175657?adults=8&children=0&infants=0&check_in=2023-02-24&check_out=2023-02-26&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'Spacious + stylish @ Coler w/ workshop + firepit',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(13 reviews)',
#   'price': '$259'},
#  {'url': '/rooms/48608440?adults=8&children=0&infants=0&check_in=2022-04-01&check_out=2022-04-03&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'The Genesis - Bike Friendly - HOT TUB OPEN!',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '15 guests',
#   'rooms': '6 bedrooms',
#   'beds': '8 beds',
#   'baths': '4.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.86',
#   'review_count': '\xa0(21 reviews)',
#   'price': '$413'},
#  {'url': '/rooms/47493236?adults=8&children=0&infants=0&check_in=2023-01-06&check_out=2023-01-08&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'Shades of Blue | Downtown Bentonville | Sleeps 8',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.86',
#   'review_count': '\xa0(28 reviews)',
#   'price': '$197'},
#  {'url': '/rooms/50879226?adults=8&children=0&infants=0&check_in=2022-07-22&check_out=2022-07-24&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': '**New** Castle by the Square',
#   'header': 'Entire guesthouse in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.98',
#   'review_count': '\xa0(47 reviews)',
#   'price': '$360'},
#  {'url': '/rooms/49370008?adults=8&children=0&infants=0&check_in=2022-12-02&check_out=2022-12-04&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'The Emerald Bungalow on Central Ave-BEST location!',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.97',
#   'review_count': '\xa0(31 reviews)',
#   'price': '$265'},
#  {'url': '/rooms/23747636?adults=8&children=0&infants=0&check_in=2022-05-20&check_out=2022-05-22&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'WalMart HQ Area Walk to the Square and Home office',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '1.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.67',
#   'review_count': '\xa0(150 reviews)',
#   'price': '$265'},
#  {'url': '/rooms/41813187?adults=8&children=0&infants=0&check_in=2022-06-17&check_out=2022-06-19&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': '*SEND IT!* Newly Renovated | Slaughter Pen Trails',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(86 reviews)',
#   'price': '$245'},
#  {'url': '/rooms/plus/33007032?adults=8&children=0&infants=0&check_in=2022-07-15&check_out=2022-07-17&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': '*the POPPY*Cozy House for Work/Fun, Walk to Square',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '3 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'PLUS',
#   'rating': '4.98',
#   'review_count': '\xa0(201 reviews)',
#   'price': '$128'},
#  {'url': '/rooms/51466486?adults=8&children=0&infants=0&check_in=2022-04-08&check_out=2022-04-10&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'The Kaleidoscope - 1 Block to Bike Trails - Near Downtown Bentonville!',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$369'},
#  {'url': '/rooms/53842760?adults=8&children=0&infants=0&check_in=2022-04-29&check_out=2022-05-01&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'The London Calling ★ 3BD w/ POOL ★ Mins to Trail ★ Fully remodeled',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '7 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(4 reviews)',
#   'price': '$316'},
#  {'url': '/rooms/42336443?adults=8&children=0&infants=0&check_in=2023-01-27&check_out=2023-01-29&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'MOD•HAUS',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.98',
#   'review_count': '\xa0(88 reviews)',
#   'price': '$180'},
#  {'url': '/rooms/48225180?adults=8&children=0&infants=0&check_in=2023-03-10&check_out=2023-03-12&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'Bentonville Playhouse the perfect location for fun',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(40 reviews)',
#   'price': '$170'},
#  {'url': '/rooms/43953256?adults=8&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': '2 Bungalows-walk to the square, bike onto trails!',
#   'header': 'Entire bungalow in Bentonville',
#   'guests': '10 guests',
#   'rooms': '5 bedrooms',
#   'beds': '6 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(11 reviews)',
#   'price': '$499'},
#  {'url': '/rooms/51196307?adults=8&children=0&infants=0&check_in=2022-05-06&check_out=2022-05-08&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': "D Street Retreat - Downtown Bentonville's Finest",
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.97',
#   'review_count': '\xa0(36 reviews)',
#   'price': '$210'},
#  {'url': '/rooms/51919304?adults=8&children=0&infants=0&check_in=2023-02-17&check_out=2023-02-19&previous_page_section_name=1000&federated_search_id=37d5601f-55dd-4386-97d8-a75e064594eb',
#   'name': 'Cozy house by Coler 2.5min ride to trail- sleeps 8',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(7 reviews)',
#   'price': '$163'},
#  {'url': '/rooms/585336259071491593?adults=8&children=0&infants=0&check_in=2022-11-04&check_out=2022-11-06&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'Pink Door ✰ Coler MTN Bike Preserve ✰ Family Flow',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$189'},
#  {'url': '/rooms/47883859?adults=8&children=0&infants=0&check_in=2023-01-27&check_out=2023-01-29&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'the PALMETTO/Near future WMHO/Greenway/8th St mkt',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '14 guests',
#   'rooms': '4 bedrooms',
#   'beds': '7 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.99',
#   'review_count': '\xa0(69 reviews)',
#   'price': '$194'},
#  {'url': '/rooms/39864150?adults=8&children=0&infants=0&check_in=2023-01-06&check_out=2023-01-08&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'Pintell Trails: Spacious 4 Bed, 3 Bath w/ Garage',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '4 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'empty',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$150'},
#  {'url': '/rooms/47701526?adults=8&children=0&infants=0&check_in=2023-01-06&check_out=2023-01-08&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'Pool/HotTub, Firepit Mile to Slaughter Pen & town',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.97',
#   'review_count': '\xa0(91 reviews)',
#   'price': '$400'},
#  {'url': '/rooms/23161645?adults=8&children=0&infants=0&check_in=2023-03-03&check_out=2023-03-05&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'Modern Townhouse at Momentary/8th St Market',
#   'header': 'Entire townhouse in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '3 beds',
#   'baths': '2.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.99',
#   'review_count': '\xa0(101 reviews)',
#   'price': '$225'},
#  {'url': '/rooms/583586116688149847?adults=8&children=0&infants=0&check_in=2022-04-15&check_out=2022-04-17&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': '[!!NEW!!] •The Hummingbird House•',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '10 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'empty',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$185'},
#  {'url': '/rooms/35416734?adults=8&children=0&infants=0&check_in=2023-02-17&check_out=2023-02-19&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'Castle Cove Bentonville...Crystal Bridges & Trails',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '10 guests',
#   'rooms': '4 bedrooms',
#   'beds': '6 beds',
#   'baths': '2.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.93',
#   'review_count': '\xa0(111 reviews)',
#   'price': '$200'},
#  {'url': '/rooms/50879226?adults=8&children=0&infants=0&check_in=2022-08-05&check_out=2022-08-07&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': '**New** Castle by the Square',
#   'header': 'Entire guesthouse in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.98',
#   'review_count': '\xa0(47 reviews)',
#   'price': '$351'},
#  {'url': '/rooms/47493236?adults=8&children=0&infants=0&check_in=2022-11-04&check_out=2022-11-06&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'Shades of Blue | Downtown Bentonville | Sleeps 8',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.86',
#   'review_count': '\xa0(28 reviews)',
#   'price': '$197'},
#  {'url': '/rooms/49370008?adults=8&children=0&infants=0&check_in=2022-07-29&check_out=2022-07-31&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'The Emerald Bungalow on Central Ave-BEST location!',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.97',
#   'review_count': '\xa0(31 reviews)',
#   'price': '$265'},
#  {'url': '/rooms/23747636?adults=8&children=0&infants=0&check_in=2022-06-17&check_out=2022-06-19&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'WalMart HQ Area Walk to the Square and Home office',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '1.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.67',
#   'review_count': '\xa0(150 reviews)',
#   'price': '$275'},
#  {'url': '/rooms/41813187?adults=8&children=0&infants=0&check_in=2022-07-08&check_out=2022-07-10&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': '*SEND IT!* Newly Renovated | Slaughter Pen Trails',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(86 reviews)',
#   'price': '$245'},
#  {'url': '/rooms/575978190876268011?adults=8&children=0&infants=0&check_in=2022-06-03&check_out=2022-06-05&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': '★ The Retreat on 4th Street - Bike to Downtown Bentonville',
#   'header': 'Entire townhouse in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$279'},
#  {'url': '/rooms/50175657?adults=8&children=0&infants=0&check_in=2022-09-16&check_out=2022-09-18&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'Spacious + stylish @ Coler w/ workshop + firepit',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(13 reviews)',
#   'price': '$329'},
#  {'url': '/rooms/plus/33007032?adults=8&children=0&infants=0&check_in=2023-01-13&check_out=2023-01-15&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': '*the POPPY*Cozy House for Work/Fun, Walk to Square',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '3 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'PLUS',
#   'rating': '4.98',
#   'review_count': '\xa0(201 reviews)',
#   'price': '$134'},
#  {'url': '/rooms/51466486?adults=8&children=0&infants=0&check_in=2022-04-08&check_out=2022-04-10&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'The Kaleidoscope - 1 Block to Bike Trails - Near Downtown Bentonville!',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$369'},
#  {'url': '/rooms/48608440?adults=8&children=0&infants=0&check_in=2022-04-15&check_out=2022-04-17&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'The Genesis - Bike Friendly - HOT TUB OPEN!',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '15 guests',
#   'rooms': '6 bedrooms',
#   'beds': '8 beds',
#   'baths': '4.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.86',
#   'review_count': '\xa0(21 reviews)',
#   'price': '$472'},
#  {'url': '/rooms/53842760?adults=8&children=0&infants=0&check_in=2022-04-29&check_out=2022-05-01&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'The London Calling ★ 3BD w/ POOL ★ Mins to Trail ★ Fully remodeled',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '7 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(4 reviews)',
#   'price': '$316'},
#  {'url': '/rooms/48225180?adults=8&children=0&infants=0&check_in=2022-08-26&check_out=2022-08-28&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': 'Bentonville Playhouse the perfect location for fun',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(40 reviews)',
#   'price': '$170'},
#  {'url': '/rooms/43953256?adults=8&children=0&infants=0&check_in=2022-07-29&check_out=2022-07-31&previous_page_section_name=1000&federated_search_id=15ee28bb-9792-4586-a03a-b77f1a07ce5a',
#   'name': '2 Bungalows-walk to the square, bike onto trails!',
#   'header': 'Entire bungalow in Bentonville',
#   'guests': '10 guests',
#   'rooms': '5 bedrooms',
#   'beds': '6 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(11 reviews)',
#   'price': '$499'},
#  {'url': '/rooms/585336259071491593?adults=8&children=0&infants=0&check_in=2023-03-03&check_out=2023-03-05&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'Pink Door ✰ Coler MTN Bike Preserve ✰ Family Flow',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': 'empty'},
#  {'url': '/rooms/47883859?adults=8&children=0&infants=0&check_in=2023-03-17&check_out=2023-03-19&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'the PALMETTO/Near future WMHO/Greenway/8th St mkt',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '14 guests',
#   'rooms': '4 bedrooms',
#   'beds': '7 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.99',
#   'review_count': '\xa0(69 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/47701526?adults=8&children=0&infants=0&check_in=2023-03-10&check_out=2023-03-12&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'Pool/HotTub, Firepit Mile to Slaughter Pen & town',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.97',
#   'review_count': '\xa0(91 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/39864150?adults=8&children=0&infants=0&check_in=2022-04-29&check_out=2022-05-01&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'Pintell Trails: Spacious 4 Bed, 3 Bath w/ Garage',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '4 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'empty',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': 'empty'},
#  {'url': '/rooms/583586116688149847?adults=8&children=0&infants=0&check_in=2023-02-17&check_out=2023-02-19&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': '[!!NEW!!] •The Hummingbird House•',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '10 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'empty',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': 'empty'},
#  {'url': '/rooms/23161645?adults=8&children=0&infants=0&check_in=2023-02-10&check_out=2023-02-12&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'Modern Townhouse at Momentary/8th St Market',
#   'header': 'Entire townhouse in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '3 beds',
#   'baths': '2.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.99',
#   'review_count': '\xa0(101 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/35416734?adults=8&children=0&infants=0&check_in=2023-02-17&check_out=2023-02-19&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'Castle Cove Bentonville...Crystal Bridges & Trails',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '10 guests',
#   'rooms': '4 bedrooms',
#   'beds': '6 beds',
#   'baths': '2.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.93',
#   'review_count': '\xa0(111 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/50175657?adults=8&children=0&infants=0&check_in=2022-09-09&check_out=2022-09-11&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'Spacious + stylish @ Coler w/ workshop + firepit',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(13 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/47493236?adults=8&children=0&infants=0&check_in=2022-11-18&check_out=2022-11-20&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'Shades of Blue | Downtown Bentonville | Sleeps 8',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.86',
#   'review_count': '\xa0(28 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/50879226?adults=8&children=0&infants=0&check_in=2022-07-29&check_out=2022-07-31&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': '**New** Castle by the Square',
#   'header': 'Entire guesthouse in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.98',
#   'review_count': '\xa0(47 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/49370008?adults=8&children=0&infants=0&check_in=2022-07-15&check_out=2022-07-17&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'The Emerald Bungalow on Central Ave-BEST location!',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.97',
#   'review_count': '\xa0(31 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/23747636?adults=8&children=0&infants=0&check_in=2022-05-20&check_out=2022-05-22&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'WalMart HQ Area Walk to the Square and Home office',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '1.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.67',
#   'review_count': '\xa0(150 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/41813187?adults=8&children=0&infants=0&check_in=2022-06-24&check_out=2022-06-26&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': '*SEND IT!* Newly Renovated | Slaughter Pen Trails',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(86 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/575978190876268011?adults=8&children=0&infants=0&check_in=2022-06-03&check_out=2022-06-05&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': '★ The Retreat on 4th Street - Bike to Downtown Bentonville',
#   'header': 'Entire townhouse in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': 'empty'},
#  {'url': '/rooms/48608440?adults=8&children=0&infants=0&check_in=2022-04-15&check_out=2022-04-17&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'The Genesis - Bike Friendly - HOT TUB OPEN!',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '15 guests',
#   'rooms': '6 bedrooms',
#   'beds': '8 beds',
#   'baths': '4.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.86',
#   'review_count': '\xa0(21 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/51466486?adults=8&children=0&infants=0&check_in=2022-04-01&check_out=2022-04-03&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'The Kaleidoscope - 1 Block to Bike Trails - Near Downtown Bentonville!',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': 'empty'},
#  {'url': '/rooms/53842760?adults=8&children=0&infants=0&check_in=2022-04-29&check_out=2022-05-01&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'The London Calling ★ 3BD w/ POOL ★ Mins to Trail ★ Fully remodeled',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '7 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(4 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/plus/33007032?adults=8&children=0&infants=0&check_in=2022-11-04&check_out=2022-11-06&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': '*the POPPY*Cozy House for Work/Fun, Walk to Square',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '3 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'PLUS',
#   'rating': '4.98',
#   'review_count': '\xa0(201 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/48225180?adults=8&children=0&infants=0&check_in=2022-08-05&check_out=2022-08-07&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': 'Bentonville Playhouse the perfect location for fun',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(40 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/43953256?adults=8&children=0&infants=0&check_in=2022-07-08&check_out=2022-07-10&previous_page_section_name=1000&federated_search_id=9f8d98e0-d5ff-47a5-a126-8ad7a38e199c',
#   'name': '2 Bungalows-walk to the square, bike onto trails!',
#   'header': 'Entire bungalow in Bentonville',
#   'guests': '10 guests',
#   'rooms': '5 bedrooms',
#   'beds': '6 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(11 reviews)',
#   'price': 'empty'},
#  {'url': '/rooms/585336259071491593?adults=8&children=0&infants=0&check_in=2022-05-20&check_out=2022-05-22&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': 'Pink Door ✰ Coler MTN Bike Preserve ✰ Family Flow',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$189'},
#  {'url': '/rooms/47701526?adults=8&children=0&infants=0&check_in=2022-12-16&check_out=2022-12-18&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': 'Pool/HotTub, Firepit Mile to Slaughter Pen & town',
#   'header': 'Entire residential home in Downtown Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.97',
#   'review_count': '\xa0(91 reviews)',
#   'price': '$400'},
#  {'url': '/rooms/47883859?adults=8&children=0&infants=0&check_in=2022-11-11&check_out=2022-11-13&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': 'the PALMETTO/Near future WMHO/Greenway/8th St mkt',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '14 guests',
#   'rooms': '4 bedrooms',
#   'beds': '7 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.99',
#   'review_count': '\xa0(69 reviews)',
#   'price': '$245'},
#  {'url': '/rooms/39864150?adults=8&children=0&infants=0&check_in=2022-07-15&check_out=2022-07-17&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': 'Pintell Trails: Spacious 4 Bed, 3 Bath w/ Garage',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '4 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'empty',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$190'},
#  {'url': '/rooms/583586116688149847?adults=8&children=0&infants=0&check_in=2022-04-01&check_out=2022-04-03&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': '[!!NEW!!] •The Hummingbird House•',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '10 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'empty',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$185'},
#  {'url': '/rooms/35416734?adults=8&children=0&infants=0&check_in=2022-12-16&check_out=2022-12-18&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': 'Castle Cove Bentonville...Crystal Bridges & Trails',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '10 guests',
#   'rooms': '4 bedrooms',
#   'beds': '6 beds',
#   'baths': '2.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.93',
#   'review_count': '\xa0(111 reviews)',
#   'price': '$200'},
#  {'url': '/rooms/45841414?adults=8&children=0&infants=0&check_in=2023-03-03&check_out=2023-03-05&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': '★The Stefani ★ 4BR 3BA 1 Mi to Square Tristan Trail ★ Bike in Bike Out',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '12 guests',
#   'rooms': '4 bedrooms',
#   'beds': '6 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': '4.91',
#   'review_count': '\xa0(34 reviews)',
#   'price': '$204'},
#  {'url': '/rooms/50879226?adults=8&children=0&infants=0&check_in=2022-08-05&check_out=2022-08-07&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': '**New** Castle by the Square',
#   'header': 'Entire guesthouse in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.98',
#   'review_count': '\xa0(47 reviews)',
#   'price': '$351'},
#  {'url': '/rooms/47493236?adults=8&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': 'Shades of Blue | Downtown Bentonville | Sleeps 8',
#   'header': 'Entire residential home in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.86',
#   'review_count': '\xa0(28 reviews)',
#   'price': '$197'},
#  {'url': '/rooms/49370008?adults=8&children=0&infants=0&check_in=2022-07-29&check_out=2022-07-31&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': 'The Emerald Bungalow on Central Ave-BEST location!',
#   'header': 'Entire residential home in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.97',
#   'review_count': '\xa0(31 reviews)',
#   'price': '$265'},
#  {'url': '/rooms/23747636?adults=8&children=0&infants=0&check_in=2022-06-17&check_out=2022-06-19&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': 'WalMart HQ Area Walk to the Square and Home office',
#   'header': 'Entire residential home in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '1.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.67',
#   'review_count': '\xa0(150 reviews)',
#   'price': '$275'},
#  {'url': '/rooms/41813187?adults=8&children=0&infants=0&check_in=2022-08-19&check_out=2022-08-21&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': '*SEND IT!* Newly Renovated | Slaughter Pen Trails',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(86 reviews)',
#   'price': '$245'},
#  {'url': '/rooms/575978190876268011?adults=8&children=0&infants=0&check_in=2022-05-27&check_out=2022-05-29&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': '★ The Retreat on 4th Street - Bike to Downtown Bentonville',
#   'header': 'Entire townhouse in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$279'},
#  {'url': '/rooms/48608440?adults=8&children=0&infants=0&check_in=2022-04-15&check_out=2022-04-17&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': 'The Genesis - Bike Friendly - HOT TUB OPEN!',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '15 guests',
#   'rooms': '6 bedrooms',
#   'beds': '8 beds',
#   'baths': '4.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.86',
#   'review_count': '\xa0(21 reviews)',
#   'price': '$472'},
#  {'url': '/rooms/51466486?adults=8&children=0&infants=0&check_in=2022-04-01&check_out=2022-04-03&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': 'The Kaleidoscope - 1 Block to Bike Trails - Near Downtown Bentonville!',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$378'},
#  {'url': '/rooms/plus/33007032?adults=8&children=0&infants=0&check_in=2023-02-17&check_out=2023-02-19&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': '*the POPPY*Cozy House for Work/Fun, Walk to Square',
#   'header': 'Entire residential home in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '3 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'PLUS',
#   'rating': '4.98',
#   'review_count': '\xa0(201 reviews)',
#   'price': '$139'},
#  {'url': '/rooms/53842760?adults=8&children=0&infants=0&check_in=2022-04-29&check_out=2022-05-01&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': 'The London Calling ★ 3BD w/ POOL ★ Mins to Trail ★ Fully remodeled',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '7 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(4 reviews)',
#   'price': '$316'},
#  {'url': '/rooms/50175657?adults=8&children=0&infants=0&check_in=2022-06-17&check_out=2022-06-19&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': 'Spacious + stylish @ Coler w/ workshop + firepit',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(13 reviews)',
#   'price': '$349'},
#  {'url': '/rooms/48225180?adults=8&children=0&infants=0&check_in=2023-02-17&check_out=2023-02-19&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': 'Bentonville Playhouse the perfect location for fun',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(40 reviews)',
#   'price': '$170'},
#  {'url': '/rooms/43953256?adults=8&children=0&infants=0&check_in=2022-10-07&check_out=2022-10-09&previous_page_section_name=1000&federated_search_id=dd011a8a-6493-426e-9213-7f32e21d250a',
#   'name': '2 Bungalows-walk to the square, bike onto trails!',
#   'header': 'Entire bungalow in Bentonville',
#   'guests': '10 guests',
#   'rooms': '5 bedrooms',
#   'beds': '6 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(11 reviews)',
#   'price': '$499'},
#  {'url': '/rooms/585336259071491593?adults=8&children=0&infants=0&check_in=2022-12-02&check_out=2022-12-04&previous_page_section_name=1000&federated_search_id=e5c04909-8d7d-43fd-9ecf-47318079a30b',
#   'name': 'Pink Door ✰ Coler MTN Bike Preserve ✰ Family Flow',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$189'},
#  {'url': '/rooms/47883859?adults=8&children=0&infants=0&check_in=2023-03-17&check_out=2023-03-19&previous_page_section_name=1000&federated_search_id=e5c04909-8d7d-43fd-9ecf-47318079a30b',
#   'name': 'the PALMETTO/Near future WMHO/Greenway/8th St mkt',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '14 guests',
#   'rooms': '4 bedrooms',
#   'beds': '7 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.99',
#   'review_count': '\xa0(69 reviews)',
#   'price': '$203'},
#  {'url': '/rooms/39864150?adults=8&children=0&infants=0&check_in=2023-02-10&check_out=2023-02-12&previous_page_section_name=1000&federated_search_id=e5c04909-8d7d-43fd-9ecf-47318079a30b',
#   'name': 'Pintell Trails: Spacious 4 Bed, 3 Bath w/ Garage',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '4 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'empty',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$150'},
#  {'url': '/rooms/47701526?adults=8&children=0&infants=0&check_in=2022-11-04&check_out=2022-11-06&previous_page_section_name=1000&federated_search_id=e5c04909-8d7d-43fd-9ecf-47318079a30b',
#   'name': 'Pool/HotTub, Firepit Mile to Slaughter Pen & town',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.97',
#   'review_count': '\xa0(91 reviews)',
#   'price': '$400'},
#  {'url': '/rooms/583586116688149847?adults=8&children=0&infants=0&check_in=2022-06-24&check_out=2022-06-26&previous_page_section_name=1000&federated_search_id=e5c04909-8d7d-43fd-9ecf-47318079a30b',
#   'name': '[!!NEW!!] •The Hummingbird House•',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '10 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'empty',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$186'},
#  {'url': '/rooms/35416734?adults=8&children=0&infants=0&check_in=2023-01-20&check_out=2023-01-22&previous_page_section_name=1000&federated_search_id=e5c04909-8d7d-43fd-9ecf-47318079a30b',
#   'name': 'Castle Cove Bentonville...Crystal Bridges & Trails',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '10 guests',
#   'rooms': '4 bedrooms',
#   'beds': '6 beds',
#   'baths': '2.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
# ...
#   'guests': '9 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$369'},
#  {'url': '/rooms/50175657?adults=8&children=0&infants=0&check_in=2022-07-01&check_out=2022-07-03&previous_page_section_name=1000&federated_search_id=6d62596d-e66c-4287-a9bd-53db132f73f7',
#   'name': 'Spacious + stylish @ Coler w/ workshop + firepit',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(13 reviews)',
#   'price': '$339'},
#  {'url': '/rooms/53842760?adults=8&children=0&infants=0&check_in=2022-04-29&check_out=2022-05-01&previous_page_section_name=1000&federated_search_id=6d62596d-e66c-4287-a9bd-53db132f73f7',
#   'name': 'The London Calling ★ 3BD w/ POOL ★ Mins to Trail ★ Fully remodeled',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '7 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(4 reviews)',
#   'price': '$316'},
#  {'url': '/rooms/558121609713867778?adults=8&children=0&infants=0&check_in=2022-04-15&check_out=2022-04-17&previous_page_section_name=1000&federated_search_id=6d62596d-e66c-4287-a9bd-53db132f73f7',
#   'name': 'The Torino ⭐ Close to MTB Trails ⭐ Family Friendly',
#   'header': 'Entire residential home in Downtown Bentonville',
#   'guests': '10 guests',
#   'rooms': '3 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$193'},
#  {'url': '/rooms/51085138?adults=8&children=0&infants=0&check_in=2022-04-15&check_out=2022-04-17&previous_page_section_name=1000&federated_search_id=6d62596d-e66c-4287-a9bd-53db132f73f7',
#   'name': 'T&L ⭐️ The Louise⭐️ 🚲 Right by Tristan Trail 🏠 Fully Remodeled 🏠',
#   'header': 'Entire townhouse in Bentonville',
#   'guests': '10 guests',
#   'rooms': '3 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.92',
#   'review_count': '\xa0(12 reviews)',
#   'price': '$134'},
#  {'url': '/rooms/48225180?adults=8&children=0&infants=0&check_in=2023-01-27&check_out=2023-01-29&previous_page_section_name=1000&federated_search_id=6d62596d-e66c-4287-a9bd-53db132f73f7',
#   'name': 'Bentonville Playhouse the perfect location for fun',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(40 reviews)',
#   'price': '$170'},
#  {'url': '/rooms/42336443?adults=8&children=0&infants=0&check_in=2022-12-09&check_out=2022-12-11&previous_page_section_name=1000&federated_search_id=6d62596d-e66c-4287-a9bd-53db132f73f7',
#   'name': 'MOD•HAUS',
#   'header': 'Entire residential home in Downtown Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.98',
#   'review_count': '\xa0(88 reviews)',
#   'price': '$185'},
#  {'url': '/rooms/43953256?adults=8&children=0&infants=0&check_in=2022-11-11&check_out=2022-11-13&previous_page_section_name=1000&federated_search_id=6d62596d-e66c-4287-a9bd-53db132f73f7',
#   'name': '2 Bungalows-walk to the square, bike onto trails!',
#   'header': 'Entire bungalow in Bentonville',
#   'guests': '10 guests',
#   'rooms': '5 bedrooms',
#   'beds': '6 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(11 reviews)',
#   'price': '$499'},
#  {'url': '/rooms/51196307?adults=8&children=0&infants=0&check_in=2022-05-06&check_out=2022-05-08&previous_page_section_name=1000&federated_search_id=6d62596d-e66c-4287-a9bd-53db132f73f7',
#   'name': "D Street Retreat - Downtown Bentonville's Finest",
#   'header': 'Entire residential home in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.97',
#   'review_count': '\xa0(36 reviews)',
#   'price': '$210'},
#  {'url': '/rooms/585336259071491593?adults=8&children=0&infants=0&check_in=2023-01-20&check_out=2023-01-22&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'Pink Door ✰ Coler MTN Bike Preserve ✰ Family Flow',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$189'},
#  {'url': '/rooms/47883859?adults=8&children=0&infants=0&check_in=2023-03-10&check_out=2023-03-12&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'the PALMETTO/Near future WMHO/Greenway/8th St mkt',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '14 guests',
#   'rooms': '4 bedrooms',
#   'beds': '7 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.99',
#   'review_count': '\xa0(69 reviews)',
#   'price': '$202'},
#  {'url': '/rooms/39864150?adults=8&children=0&infants=0&check_in=2023-02-17&check_out=2023-02-19&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'Pintell Trails: Spacious 4 Bed, 3 Bath w/ Garage',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '4 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'empty',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$150'},
#  {'url': '/rooms/47701526?adults=8&children=0&infants=0&check_in=2023-02-17&check_out=2023-02-19&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'Pool/HotTub, Firepit Mile to Slaughter Pen & town',
#   'header': 'Entire residential home in Downtown Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.97',
#   'review_count': '\xa0(91 reviews)',
#   'price': '$400'},
#  {'url': '/rooms/23161645?adults=8&children=0&infants=0&check_in=2023-01-27&check_out=2023-01-29&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'Modern Townhouse at Momentary/8th St Market',
#   'header': 'Entire townhouse in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '3 beds',
#   'baths': '2.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.99',
#   'review_count': '\xa0(101 reviews)',
#   'price': '$225'},
#  {'url': '/rooms/583586116688149847?adults=8&children=0&infants=0&check_in=2022-06-24&check_out=2022-06-26&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': '[!!NEW!!] •The Hummingbird House•',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '10 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'empty',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$186'},
#  {'url': '/rooms/35416734?adults=8&children=0&infants=0&check_in=2023-03-03&check_out=2023-03-05&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'Castle Cove Bentonville...Crystal Bridges & Trails',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '10 guests',
#   'rooms': '4 bedrooms',
#   'beds': '6 beds',
#   'baths': '2.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.93',
#   'review_count': '\xa0(111 reviews)',
#   'price': '$200'},
#  {'url': '/rooms/48608440?adults=8&children=0&infants=0&check_in=2022-04-01&check_out=2022-04-03&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'The Genesis - Bike Friendly - HOT TUB OPEN!',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '15 guests',
#   'rooms': '6 bedrooms',
#   'beds': '8 beds',
#   'baths': '4.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.86',
#   'review_count': '\xa0(21 reviews)',
#   'price': '$413'},
#  {'url': '/rooms/47493236?adults=8&children=0&infants=0&check_in=2023-01-20&check_out=2023-01-22&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'Shades of Blue | Downtown Bentonville | Sleeps 8',
#   'header': 'Entire residential home in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.86',
#   'review_count': '\xa0(28 reviews)',
#   'price': '$197'},
#  {'url': '/rooms/49370008?adults=8&children=0&infants=0&check_in=2022-11-04&check_out=2022-11-06&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'The Emerald Bungalow on Central Ave-BEST location!',
#   'header': 'Entire residential home in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.97',
#   'review_count': '\xa0(31 reviews)',
#   'price': '$265'},
#  {'url': '/rooms/50175657?adults=8&children=0&infants=0&check_in=2022-11-25&check_out=2022-11-27&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'Spacious + stylish @ Coler w/ workshop + firepit',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '6 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(13 reviews)',
#   'price': '$299'},
#  {'url': '/rooms/50879226?adults=8&children=0&infants=0&check_in=2022-07-15&check_out=2022-07-17&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': '**New** Castle by the Square',
#   'header': 'Entire guesthouse in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.98',
#   'review_count': '\xa0(47 reviews)',
#   'price': '$380'},
#  {'url': '/rooms/45841414?adults=8&children=0&infants=0&check_in=2022-12-02&check_out=2022-12-04&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': '★The Stefani ★ 4BR 3BA 1 Mi to Square Tristan Trail ★ Bike in Bike Out',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '12 guests',
#   'rooms': '4 bedrooms',
#   'beds': '6 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': '4.91',
#   'review_count': '\xa0(34 reviews)',
#   'price': '$224'},
#  {'url': '/rooms/23747636?adults=8&children=0&infants=0&check_in=2022-05-20&check_out=2022-05-22&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'WalMart HQ Area Walk to the Square and Home office',
#   'header': 'Entire residential home in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '6 beds',
#   'baths': '1.5 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '4.67',
#   'review_count': '\xa0(150 reviews)',
#   'price': '$265'},
#  {'url': '/rooms/41813187?adults=8&children=0&infants=0&check_in=2022-07-15&check_out=2022-07-17&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': '*SEND IT!* Newly Renovated | Slaughter Pen Trails',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '4 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(86 reviews)',
#   'price': '$245'},
#  {'url': '/rooms/575978190876268011?adults=8&children=0&infants=0&check_in=2022-07-29&check_out=2022-07-31&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': '★ The Retreat on 4th Street - Bike to Downtown Bentonville',
#   'header': 'Entire townhouse in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$279'},
#  {'url': '/rooms/51466486?adults=8&children=0&infants=0&check_in=2022-04-08&check_out=2022-04-10&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'The Kaleidoscope - 1 Block to Bike Trails - Near Downtown Bentonville!',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '3 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': 'empty',
#   'review_count': 'empty',
#   'price': '$369'},
#  {'url': '/rooms/plus/33007032?adults=8&children=0&infants=0&check_in=2023-01-20&check_out=2023-01-22&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': '*the POPPY*Cozy House for Work/Fun, Walk to Square',
#   'header': 'Entire residential home in Downtown Bentonville',
#   'guests': '8 guests',
#   'rooms': '3 bedrooms',
#   'beds': '3 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'PLUS',
#   'rating': '4.98',
#   'review_count': '\xa0(201 reviews)',
#   'price': '$135'},
#  {'url': '/rooms/53842760?adults=8&children=0&infants=0&check_in=2022-04-29&check_out=2022-05-01&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'The London Calling ★ 3BD w/ POOL ★ Mins to Trail ★ Fully remodeled',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '9 guests',
#   'rooms': '3 bedrooms',
#   'beds': '7 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(4 reviews)',
#   'price': '$316'},
#  {'url': '/rooms/48225180?adults=8&children=0&infants=0&check_in=2023-01-20&check_out=2023-01-22&previous_page_section_name=1000&federated_search_id=468609a2-aa92-4c10-8eb0-2227975b8829',
#   'name': 'Bentonville Playhouse the perfect location for fun',
#   'header': 'Entire residential home in Bentonville',
#   'guests': '8 guests',
#   'rooms': '4 bedrooms',
#   'beds': '5 beds',
#   'baths': '2 baths',
#   'facilities': 'Wifi · Kitchen · Free parking · Self check-in',
#   'badge': 'SUPERHOST',
#   'rating': '5.0',
#   'review_count': '\xa0(40 reviews)',
#   'price': '$170'}]

# %%
landing_page_df = pd.DataFrame.from_dict(base_features, orient='columns')

landing_page_df
# Out:
#                                                    url  \
# 0    /rooms/585336259071491593?adults=8&children=0&...
# 1    /rooms/47883859?adults=8&children=0&infants=0&...
# 2    /rooms/47701526?adults=8&children=0&infants=0&...
# 3    /rooms/39864150?adults=8&children=0&infants=0&...
# 4    /rooms/583586116688149847?adults=8&children=0&...
# ..                                                 ...
# 295  /rooms/53842760?adults=8&children=0&infants=0&...
# 296  /rooms/51085138?adults=8&children=0&infants=0&...
# 297  /rooms/48225180?adults=8&children=0&infants=0&...
# 298  /rooms/42336443?adults=8&children=0&infants=0&...
# 299  /rooms/43953256?adults=8&children=0&infants=0&...
#
#                                                   name  \
# 0    Pink Door ✰ Coler MTN Bike Preserve ✰ Family Flow
# 1    the PALMETTO/Near future WMHO/Greenway/8th St mkt
# 2    Pool/HotTub, Firepit Mile to Slaughter Pen & town
# 3     Pintell Trails: Spacious 4 Bed, 3 Bath w/ Garage
# 4                    [!!NEW!!] •The Hummingbird House•
# ..                                                 ...
# 295  The London Calling ★ 3BD w/ POOL ★ Mins to Tra...
# 296  T&L ⭐️ The Louise⭐️ 🚲 Right by Tristan Trail 🏠...
# 297  Bentonville Playhouse the perfect location for...
# 298                                           MOD•HAUS
# 299  2 Bungalows-walk to the square, bike onto trails!
#
#                                      header     guests       rooms    beds  \
# 0    Entire residential home in Bentonville   8 guests  4 bedrooms  5 beds
# 1    Entire residential home in Bentonville  14 guests  4 bedrooms  7 beds
# 2    Entire residential home in Bentonville   9 guests  3 bedrooms  6 beds
# 3    Entire residential home in Bentonville   8 guests  4 bedrooms  4 beds
# 4    Entire residential home in Bentonville  10 guests  3 bedrooms  6 beds
# ..                                      ...        ...         ...     ...
# 295  Entire residential home in Bentonville   9 guests  3 bedrooms  7 beds
# 296         Entire townhouse in Bentonville  10 guests  3 bedrooms  5 beds
# 297  Entire residential home in Bentonville   8 guests  4 bedrooms  5 beds
# 298  Entire residential home in Bentonville   9 guests  3 bedrooms  5 beds
# 299          Entire bungalow in Bentonville  10 guests  5 bedrooms  6 beds
#
#        baths                                     facilities      badge rating  \
# 0    3 baths                  Wifi · Kitchen · Free parking  SUPERHOST  empty
# 1    3 baths  Wifi · Kitchen · Free parking · Self check-in  SUPERHOST   4.99
# 2    2 baths  Wifi · Kitchen · Free parking · Self check-in  SUPERHOST   4.97
# 3    3 baths  Wifi · Kitchen · Free parking · Self check-in      empty  empty
# 4    2 baths  Wifi · Kitchen · Free parking · Self check-in      empty  empty
# ..       ...                                            ...        ...    ...
# 295  2 baths                  Wifi · Kitchen · Free parking  SUPERHOST    5.0
# 296  2 baths  Wifi · Kitchen · Free parking · Self check-in  SUPERHOST   4.92
# 297  2 baths  Wifi · Kitchen · Free parking · Self check-in  SUPERHOST    5.0
# 298  2 baths  Wifi · Kitchen · Free parking · Self check-in  SUPERHOST   4.98
# 299  3 baths  Wifi · Kitchen · Free parking · Self check-in  SUPERHOST    5.0
#
#       review_count price
# 0            empty  $189
# 1     (69 reviews)  $197
# 2     (91 reviews)  $438
# 3            empty  $180
# 4            empty  $165
# ..             ...   ...
# 295    (4 reviews)  $316
# 296   (12 reviews)  $134
# 297   (40 reviews)  $170
# 298   (88 reviews)  $187
# 299   (11 reviews)  $499
#
# [300 rows x 12 columns]

# %%
# listing name: div, _xcsyj0
detail_url = 'https://airbnb.com' + base_features[0]['url']
print(f'{detail_url}\n')

answer = requests.get(detail_url)
print(f'{answer}\n')

detail_soup = BeautifulSoup(answer.content)

detail_soup = detail_soup.find('h2', '_14i3z6h')

# some JS functions inside
for a in detail_soup:
    print(a.text)
# Out:
# https://airbnb.com/rooms/585336259071491593?adults=8&children=0&infants=0&check_in=2023-03-03&check_out=2023-03-05&previous_page_section_name=1000&federated_search_id=81494fa7-69be-49e0-8220-f98a6115a434
#
# <Response [200]>
#
# Entire residential home hosted by Pink Door BnB

# %%
ser = Service("/usr/local/bin/chromedriver")
op = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=ser, options=op)

#opening page
reviews =driver.get(detail_url)

print(reviews)
time.sleep(10)

# getting html
page_detailed = driver.page_source

# closing the driver
driver.quit()

detail_soup = BeautifulSoup(page_detailed)

detail_soup = detail_soup.find_all('span', 'll4r2nl dir dir-ltr')

for a in detail_soup:
    print(f'{a.text}\n')
# Out:
# None
# Family Flow - named for a favorite nearby Coler Mountain Bike Trail - is a colorful, fun filled home perfect for a family or fun group of friends. Enjoy a professionally decorated space, inspired by the art and nature Bentonville is famous for. Each room is unique and certain to ensure every person in your party will be happy with their accomodations.
#
# Enjoy comfy, 100% cotton bedding for a great night's sleep, a fully stocked kitchen (just bring the snacks!), a private bedroom upstairs (with games and TV) for kids to have their own unique space to enjoy, 3 full bathrooms, a smart TV, a gas fireplace and a fully stocked back deck that overlooks the street entrance to Coler MTN Bike Preserve.
#
# Walk to the Gorgeous Airship coffee house located within the nature preserve. 5 minutes drive to Bentonville Town Square.
#
# Book now for Coler specific events - this home is the closest Airbnb to Coler! We are inclusive and do no discriminate - all are welcome!
#
# This host has 251 reviews for other places to stay. Show other reviews
#
# We’re here to help your trip go smoothly. Every reservation is covered by Airbnb’s Guest Refund Policy.
#
# Nestled right next door to Coler Mtn Bike Preserve
# Walking Distance to Airship coffee (in the nature preserve)
# 5 minutes to downtown Bentonville
#
# Pink Door BnB is owned and Managed by Jared and Suzanna Styles, who moved to Bentonville from Austin TX in 2018 because Jared needed more mountain biking in his life. Suzanna soon found out (shoutout to Women of Oz) that she loves mountain biking too! Jared and Suz live in downtown Bentonville with their 2 daughters, 3 dogs and 50 plants. However, our team is made up of a diverse group of talented individuals including a realtor, broker, cleaning crew, quality control, maintenance, yard maintenance etc etc. It takes a village and we sure are thankful for ours! We value cleanliness, timely communication, inclusivity and creating beautiful spaces where lifelong memories can be made. It is our sincerest hope that you will be telling and retelling memories from your travels for years to come and even returning to our homes to make new ones! Follow our journey @pinkdoorbnb
#
# Pink Door BnB is owned and Managed by Jared and Suzanna Styles, who moved to Bentonville from Austin TX in 2018 because Jared needed more mountain biking in his life. Suzanna soon…
#
# Pink Door BnB is available 9am - 5pm for all non emergency requests and extended hours for emergencies. Connect with us @pinkdoorbnb or visit www.pinkdoorbnb.com to inquire about our management and design services. We look forward to hosting you!
#
# Pink Door BnB is available 9am - 5pm for all non emergency requests and extended hours for emergencies. Connect with us @pinkdoorbnb or visit www.pinkdoorbnb.com to inquire about o…
#
# Superhosts are experienced, highly rated hosts who are committed to providing great stays for guests.
#
# 100%
#
# within an hour
#
# Free cancellation before Mar 2

# %%
# amenities button
ser = Service("/usr/local/bin/chromedriver")
op = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=ser, options=op)

driver.get(detail_url)
time.sleep(20)
driver.find_element(by=By.PARTIAL_LINK_TEXT, value='amenities').click()

# %%
page_detailed = driver.page_source
time.sleep(20)
detail_soup_clicked = BeautifulSoup(page_detailed)

# %%
time.sleep(10)
amenities = detail_soup_clicked.find_all('div', {'class': '_gw4xx4'})


amenities_all = [amenitie.text for amenitie in amenities]

# for i in url_list:
#     print(url_list + amenities_all)

amenities_all
# Out:
# ['Hair dryer',
#  'Shampoo',
#  'Hot water',
#  'Washer',
#  'Dryer',
#  'Essentials',
#  'Hangers',
#  'Bed linens',
#  'Room-darkening shades',
#  'Iron',
#  'TV',
#  'Pack ’n play/Travel crib',
#  'Children’s books and toys',
#  'High chair',
#  'Air conditioning',
#  'Indoor fireplace',
#  'Heating',
#  'Smoke alarm',
#  'Carbon monoxide alarm',
#  'Fire extinguisher',
#  'First aid kit',
#  'Wifi',
#  'Dedicated workspace',
#  'Kitchen',
#  'Refrigerator',
#  'Microwave',
#  'Cooking basics',
#  'Dishes and silverware',
#  'Dishwasher',
#  'Stove',
#  'Oven',
#  'Coffee maker',
#  'Patio or balcony',
#  'Outdoor furniture',
#  'Hammock',
#  'Outdoor dining area',
#  'BBQ grill',
#  'Free parking on premises',
#  'Free street parking',
#  'Pets allowed',
#  'Long term stays allowed',
#  'Unavailable: Security cameras on propertySecurity cameras on property',
#  'Unavailable: Private entrancePrivate entrance']

# %%
def extract_element(listing_html, params):
    # 1. Find the right tag
    if 'class' in params:
        elements_found = listing_html.find_all(params['tag'], params['class'])
    else:
        elements_found = listing_html.find_all(params['tag'])

    # 2. Extract text from these tags
    if 'get' in params:
        element_texts = [el.get(params['get']) for el in elements_found]
    else:
        element_texts = [el.get_text() for el in elements_found]
    
    # 2. Extract the right element
    tag_order = params.get('order', 0)
    element = elements_found[tag_order]
        
    # 3. Select a particular text or concatenate all of them
    tag_order = params.get('order', 0)
    if tag_order == -1:
        output = ' // '.join(element_texts)
    else:
        output = element_texts[tag_order]

    return output

# %%
#attempting house rules
house_rules = extract_element(detail_soup_clicked, {'tag': 'div', 'class': 'c1lue5su dir dir-ltr', 'order': 0})

house_rules
# Out:
# 'House rulesCheck-in: FlexibleCheckout: 11:00 AMNo smokingNo parties or eventsPets are allowedShow more'

# %%
RULES_DETAIL_PAGE = {
    'location': {'tag': 'span', 'class': '_8vvkqm3'},
    'specialties_1': {'tag': 'div', 'class': '_1qsawv5', 'order': -1},
    'host_joined': {'tag': 'li', 'class': '_194e2vt2', 'order': 1},
    'house_rules': {'tag': 'div', 'class': '_u827kd', 'order': 0},
}


def extract_soup_js(listing_url, waiting_time=[3, 1]):
    """Extracts HTML from JS pages: open, wait, click, wait, extract"""

    options = Options()
    options.add_argument('--headless')
    options.add_argument('--blink-settings=imagesEnabled=false')
    driver = webdriver.Chrome(options=options)

    driver.get(listing_url)
    time.sleep(waiting_time[0])
        
        
    driver.execute_script("window.scrollTo(0, 0);")
    try:
        driver.find_element(By.CLASS_NAME, "b1sec48q v7aged4 dir dir-ltr")
    except:
        pass # amentities button not found

    time.sleep(waiting_time[1])

    detail_page = driver.page_source

    driver.quit()

    return BeautifulSoup(detail_page, features='html.parser')

# %%
# Scrape single detail page
def process_detail_page(url):
    soup = extract_soup_js(url, waiting_time=[3, 1])
    
    features_list = []
    features = extract_page_features(soup, RULES_DETAIL_PAGE)
    features['amenities'] = amenities_all
    features_list.append(features)

    return features_list


t0 = time.time()
detail_features = process_detail_page(detail_url)
# print(time.time() - t0)
print(detail_features)
# Out:
# [{'location': 'Bentonville, Arkansas, United States', 'specialties_1': 'Pink Door BnB is a Superhost // Free cancellation before Mar 2', 'host_joined': 'empty', 'house_rules': 'empty', 'amenities': ['Hair dryer', 'Shampoo', 'Hot water', 'Washer', 'Dryer', 'Essentials', 'Hangers', 'Bed linens', 'Room-darkening shades', 'Iron', 'TV', 'Pack ’n play/Travel crib', 'Children’s books and toys', 'High chair', 'Air conditioning', 'Indoor fireplace', 'Heating', 'Smoke alarm', 'Carbon monoxide alarm', 'Fire extinguisher', 'First aid kit', 'Wifi', 'Dedicated workspace', 'Kitchen', 'Refrigerator', 'Microwave', 'Cooking basics', 'Dishes and silverware', 'Dishwasher', 'Stove', 'Oven', 'Coffee maker', 'Patio or balcony', 'Outdoor furniture', 'Hammock', 'Outdoor dining area', 'BBQ grill', 'Free parking on premises', 'Free street parking', 'Pets allowed', 'Long term stays allowed', 'Unavailable: Security cameras on propertySecurity cameras on property', 'Unavailable: Private entrancePrivate entrance']}]
